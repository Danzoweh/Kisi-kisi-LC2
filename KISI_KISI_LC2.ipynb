# %%
from google.colab import auth
from google.cloud import bigquery
auth.authenticate_user()
print('Authenticated')

project_id = "bigquaryw2d3pm" #GUNAKAN GCP PROJECT-ID KALIAN MASING-MASING
client = bigquery.Client(project=project_id)
# Out:
# Authenticated
# Authenticated

# %%
sql_query = """
SELECT *
  FROM ftds-hacktiv8-project.practice.bike_rent;
  """

# %%
df = client.query(sql_query).to_dataframe()

df
# Out:
#        trip_id subscriber_type bike_id bike_type                start_time  \
# 0     18896589        Explorer      93   classic 2018-10-28 14:16:14+00:00
# 1     13948351        Local365     315   classic 2017-03-07 12:37:33+00:00
# 2     16243803        Local365     877   classic 2017-10-21 09:49:48+00:00
# 3     16222446         Walk Up     273   classic 2017-10-18 15:01:52+00:00
# 4     16222451         Walk Up     201   classic 2017-10-18 15:02:26+00:00
# ...        ...             ...     ...       ...                       ...
# 7995  15469480         Walk Up     327   classic 2017-07-22 20:17:46+00:00
# 7996  16130650         Walk Up     528   classic 2017-10-07 11:25:36+00:00
# 7997  14204138         Walk Up     235   classic 2017-03-27 13:19:02+00:00
# 7998  15037809         Walk Up     206   classic 2017-06-05 11:42:40+00:00
# 7999   9499076         Walk Up     315   classic 2016-04-09 18:52:09+00:00
#
#                            start_station_name  \
# ...

# %% [markdown]
# 1. Berapa banyak label unique dari bike_type?

# %%
df["bike_type"].nunique()
# Out:
# 2

# %% [markdown]
#  Apa saja nama label unique dari tipe sepeda?

# %%
df["bike_type"].unique()
# Out:
# array(['classic', 'electric'], dtype=object)

# %%
df = pd.DataFrame(data)

df['tanggal'] = pd.to_datetime(df['tanggal'])

# Filter data untuk tahun 2016 dan 2017
df_filtered = df[(df['date_time'].dt.year == 2016) | (df['date_time'].dt.year == 2017)]

# Menghitung total peminjaman untuk tahun 2016 dan 2017
total_peminjaman = df_filtered[''].sum()

# Menampilkan total peminjaman
print(f"Total peminjaman sepeda pada tahun 2016 dan 2017: {total_peminjaman}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-bf9975de76c2> in <cell line: 1>()
# ----> 1 df = pd.DataFrame(data)
#       2
#       3 df['tanggal'] = pd.to_datetime(df['tanggal'])
#       4
#       5 # Filter data untuk tahun 2016 dan 2017
#
# NameError: name 'pd' is not defined

# %% [markdown]
# 3. Berapa banyak total peminjaman sepeda pada tahun 2016 dan 2017?

# %%
query = """
SELECT COUNT(*) AS total_peminjaman
FROM `ftds-hacktiv8-project.practice.bike_rent`
WHERE EXTRACT(YEAR FROM TIMESTAMP(start_time)) BETWEEN 2016 AND 2017
"""

df = client.query(query).to_dataframe()
df
# Out:
#    total_peminjaman
# 0              7993

# %%
MostStation = df ["start_station_name"].value_counts()

print(MostStation)

df = client.query(query).to_dataframe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 MostStation = df ["start_station_name"].value_counts()
#       3 print(MostStation)
#       5 df = client.query(query).to_dataframe()
#
# NameError: name 'df' is not defined
